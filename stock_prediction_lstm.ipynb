# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import math

import yfinance as yf
import datetime as dt
from datetime import timedelta
import mplfinance as mpf

import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Bidirectional
from tensorflow.keras.layers import LSTM, Embedding, SpatialDropout1D, Dropout
from tensorflow.keras.models import Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
COMPANY_NAME = "AAPL"

# %%
company_ticker = yf.Ticker(COMPANY_NAME)

df = company_ticker.history(start='2016-01-12', end=None)
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2016-01-12 00:00:00-05:00   46.538011   46.837915   45.920565   46.555653
# 2016-01-13 00:00:00-05:00   47.455350   47.693509   45.250176   45.550079
# 2016-01-14 00:00:00-05:00   45.867620   47.120157   45.488330   46.846718
# 2016-01-15 00:00:00-05:00   45.259008   45.841174   44.403399   44.976746
# 2016-01-19 00:00:00-05:00   45.408937   45.585352   44.156400   44.597435
# ...                               ...         ...         ...         ...
# 2025-01-03 00:00:00-05:00  421.079987  424.029999  419.540009  423.350006
# 2025-01-06 00:00:00-05:00  428.000000  434.320007  425.480011  427.850006
# 2025-01-07 00:00:00-05:00  429.000000  430.649994  420.799988  422.369995
# 2025-01-08 00:00:00-05:00  423.459991  426.970001  421.540009  424.559998
# 2025-01-10 00:00:00-05:00  424.630005  424.709991  415.019989  418.950012
#
#                              Volume  Dividends  Stock Splits
# Date
# 2016-01-12 00:00:00-05:00  36095500        0.0           0.0
# 2016-01-13 00:00:00-05:00  66883600        0.0           0.0
# 2016-01-14 00:00:00-05:00  52381900        0.0           0.0
# 2016-01-15 00:00:00-05:00  71820700        0.0           0.0
# 2016-01-19 00:00:00-05:00  43564500        0.0           0.0
# ...                             ...        ...           ...
# 2025-01-03 00:00:00-05:00  16662900        0.0           0.0
# 2025-01-06 00:00:00-05:00  20573600        0.0           0.0
# 2025-01-07 00:00:00-05:00  18139100        0.0           0.0
# 2025-01-08 00:00:00-05:00  15054600        0.0           0.0
# 2025-01-10 00:00:00-05:00  20186800        0.0           0.0
#
# [2264 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
df.shape
# Out:
# (2264, 7)

# %%
df['Volume'] = df['Volume'].astype('float64')

# %%
# Returns True if there are duplicate rows
has_duplicates = df.duplicated().any()

print(has_duplicates)
# Out:
# False

# %%
has_nan = df.isna().any().any()

print(has_nan)  # Returns True if there are any NaN values
# Out:
# False

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2264.000000  2264.000000  2264.000000  2264.000000  2.264000e+03
# mean    198.697684   200.579357   196.706783   198.732831  2.802070e+07
# std     121.052004   122.083537   119.910276   121.040097  1.258455e+07
# min      42.939162    43.724196    42.506939    43.326283  7.164500e+06
# 25%      88.144619    88.783296    86.811144    87.682539  2.008680e+07
# 50%     195.066041   196.914449   192.813984   195.233841  2.483605e+07
# 75%     287.231506   288.895315   284.096746   287.368118  3.212352e+07
# max     465.228569   466.573450   462.698189   465.786438  1.335030e+08
#
#          Dividends  Stock Splits
# count  2264.000000        2264.0
# mean      0.008600           0.0
# std       0.069728           0.0
# min       0.000000           0.0
# 25%       0.000000           0.0
# 50%       0.000000           0.0
# 75%       0.000000           0.0
# max       0.830000           0.0

# %%
# finding unique data
df.apply(lambda x: len(x.unique()))
# Out:
# Open            2264
# High            2262
# Low             2261
# Close           2206
# Volume          2256
# Dividends         11
# Stock Splits       1
# dtype: int64

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues',
            linewidths=.6 , cbar = False)
plt.title('Analysis of Coorelations', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
plt.show()

# %%
columns=['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']

# %%
palette = "GnBu"
for column in columns:
    plt.figure(figsize=(20,6))
    sns.boxplot(x=df[column], palette=palette)
    plt.title(f'Distribution of {column}', fontsize=15)
    plt.xlabel(column, fontsize=15)
    stats = df[column].describe()
    stats_text = "\n".join([f'{key}: {value:.2f}' for key, value in stats.items()])
    plt.text(0.95,0.95, stats_text, transform=plt.gca().transAxes,
             fontsize=10, verticalalignment='top', horizontalalignment='center',
             bbox=dict(boxstyle='round, pad=0.2', edgecolor='black',facecolor='#f4a261'))
    plt.grid(True)
    plt.show()

# %%
x = df.index
colors = ['#264653', '#2a9d8f', '#f4a261', '#e76f51','#e9c46a', '#e9d8a6']
plt.figure(figsize=(28,10))
plt.subplot(3,2,1)
plt.plot(x, df['Open'], color=colors[0], linewidth=2)
plt.title('Open', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3,2,2)
plt.plot(x,df['High'], color=colors[1], linewidth=2)
plt.title('High', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3,2,3)
plt.plot(x, df['Low'], color=colors[2], linewidth=2)
plt.title('Low', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3,2,4)
plt.plot(x, df['Close'], color=colors[3], linewidth=2)
plt.title('Close', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 5)
plt.plot(x, df['Volume'], color=colors[4], linewidth=2)
plt.title('Volume', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 6)
plt.plot(x, df['Dividends'], color=colors[5], linewidth=2)
plt.title('Dividends', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.suptitle(f'{COMPANY_NAME} Stock Attributes from 2016 to 2024', fontsize=22, y=0.98)
plt.tight_layout()
plt.show()

# %%
colors = ['#264653', '#2a9d8f', '#f4a261', '#e76f51', '#e9c46a', '#e9d8a6']

df_weekly = df.asfreq('W', method='ffill')
df_weekly.plot(subplots=True, figsize=(15,15), style='-', color=colors, linewidth=2)
plt.suptitle(f"{COMPANY_NAME} Stock Weekly Frequency Attributes", fontsize=20, y=0.95)

for ax in plt.gcf().get_axes():
    ax.grid(True, linestyle='--', alpha=0.5)
    ax.set_title(ax.get_title(), fontsize=14)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
colors = ['#264653', '#2a9d8f', '#f4a261', '#e76f51', '#e9c46a', '#e9d8a6']
df_weekly = df.asfreq('M', method='ffill')
df_weekly.plot(subplots=True, figsize=(15, 15), style='-', color=colors, linewidth=2)
plt.suptitle(f'{COMPANY_NAME} Stock Attributes Over Time (Monthly Frequency)', fontsize=20, y=0.95)
for ax in plt.gcf().get_axes():
    ax.grid(True, linestyle='--', alpha=0.5)
    ax.set_title(ax.get_title(), fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Candlestick char
candle = go.Candlestick(x=df.index, open=df['Open'],
                        high=df['High'], low=df['Low'],
                        close=df['Close'],name='Candlestick',
                        increasing=dict(line=dict(color='#2a9d8f')),
                        decreasing=dict(line=dict(color='#f4a261')))

layout = go.Layout(title=f'{COMPANY_NAME} Candlestick Chart',
                   xaxis=dict(title='Date', color='#2a9d8f'),
                   yaxis=dict(title='Price', color='#2a9d8f',rangemode='normal'),
                   plot_bgcolor='rgba(0,0,0,0)',
                   paper_bgcolor='rgba(255,255,255,0.85)')

fig = go.Figure(data=[candle], layout=layout)

# fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a51880ff-13e8-4a65-8790-31fc9d786bf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a51880ff-13e8-4a65-8790-31fc9d786bf0")) {                    Plotly.newPlot(                        "a51880ff-13e8-4a65-8790-31fc9d786bf0",                        [{"close":[46.5556526184082,45.550079345703125,46.846717834472656,44.97674560546875,44.597434997558594,44.800331115722656,44.526893615722656,46.12343215942383,45.682395935058594,46.01758575439453,45.17961502075195,45.920555114746094,48.59321594238281,48.258033752441406,46.74968719482422,46.008766174316406,45.86763000488281,44.24461364746094,43.583065032958984,43.4683952331543,43.847694396972656,43.83005142211914,44.54452896118164,45.38850021362305,46.570091247558594,46.365753173828125,46.037044525146484,46.7744140625,45.46845626831055,45.62836456298828,46.285797119140625,45.57508087158203,45.20194625854492,46.71223831176758,47.040931701660156,46.50788879394531,46.223602294921875,45.335205078125,45.88600540161133,46.94321823120117,46.241363525390625,47.14753341674805,47.23637008666992,47.60951614379883,48.28470230102539,48.560096740722656,47.52067184448242,47.84938049316406,48.035945892333984,47.947105407714844,48.16032028198242,47.56509017944336,48.60452651977539,48.90659713745117,49.06648254394531,49.36854553222656,49.24416732788086,48.47126388549805,48.96876525878906,48.38241195678711,48.34688949584961,48.24916458129883,48.55123519897461,49.17310333251953,49.18197250366211,49.43963623046875,50.15922546386719,50.09703826904297,49.38631820678711,49.555118560791016,46.00151443481445,46.29468536376953,45.6994514465332,45.255245208740234,44.33131790161133,44.304656982421875,44.962066650390625,44.224693298339844,44.304656982421875,44.366844177246094,44.76662063598633,44.48234558105469,45.326316833496094,45.35296630859375,45.76164245605469,45.37963104248047,46.045928955078125,45.18709182739258,45.45547866821289,45.017112731933594,45.285499572753906,44.75768280029297,46.153282165527344,46.627418518066406,46.42165756225586,46.80634689331055,47.414676666259766,47.280494689941406,46.94947814941406,46.33220291137695,46.636375427246094,46.609535217285156,46.55585479736328,46.180118560791016,46.054866790771484,44.85608673095703,44.578758239746094,44.45351028442383,45.079734802246094,44.847145080566406,44.79347229003906,45.795433044433594,45.616519927978516,46.43954849243164,44.578758239746094,43.3262825012207,44.22985076904297,45.21392059326172,45.77753448486328,45.76858139038086,45.77753448486328,45.96541213989258,45.96541213989258,46.788455963134766,47.047889709472656,47.60255813598633,47.870948791503906,48.076717376708984,48.04093551635742,48.27350616455078,47.49519348144531,50.01802062988281,49.91960906982422,50.608463287353516,50.75160217285156,50.778446197509766,50.26851272583008,50.286399841308594,50.70686721801758,50.617408752441406,50.617408752441406,50.9663200378418,51.3420524597168,51.851993560791016,51.94145584106445,52.06669616699219,51.90565872192383,52.156158447265625,51.83409881591797,51.99512481689453,51.707061767578125,51.81509780883789,51.851097106933594,51.86909103393555,51.91410827636719,52.112144470214844,52.166160583496094,52.36419677734375,52.2381706237793,52.301185607910156,52.112144470214844,51.72507095336914,51.84209060668945,51.91410827636719,51.86009216308594,51.90511703491211,51.698062896728516,50.599815368652344,51.35599899291992,50.88788986206055,50.64482498168945,51.48202133178711,51.53602600097656,51.247962951660156,51.13994598388672,51.99512481689453,52.049129486083984,51.698062896728516,51.2209587097168,52.166160583496094,52.2381706237793,51.67106246948242,51.851097106933594,51.689056396484375,51.52702331542969,51.88710021972656,51.97713088989258,52.0 ...

# %%
plt.figure(figsize=(10,6))
df['Open'].resample('A').mean().plot(kind='bar', color='#2a9d8f')

plt.title('Yearly Mean Open from 2014 to 2025', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Mean Open Price', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
df['Close'].resample('A').mean().plot(kind='bar', color='#f4a261')

plt.title('Yearly Mean Close from 2014 to 2025', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Mean Close Price', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['High'].resample('A').mean().plot(kind='bar', color='#005f73')
plt.title('Yearly Mean High from 2014 to 2024', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Mean High Price', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['Low'].resample('A').mean().plot(kind='bar', color='#ee9b00')
plt.title('Yearly Mean Low from 2016 to 2024', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Mean Low Price', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df1 = df.copy()
df1.drop("Stock Splits", axis=1, inplace=True)
fig = plt.figure(figsize = (20,10))
ax = fig.gca()
hist=df1.hist(ax = ax , color= '#2a9d8f')

# %% [markdown]
# ### SMA (Simple Moving Average)

# %%
md = [10, 20, 50]

for SMA in md:
    col = f'SMA for {SMA} days'
    df[col] = df['Close'].rolling(SMA).mean()

df[['Close', 'SMA for 10 days', 'SMA for 20 days', 'SMA for 50 days']].plot(figsize=(15,5))
plt.title('Comparison between SMA and Close Price', fontsize=15)
plt.show()

# %%
df['Daily Return'] = df['Close'].pct_change()
df['Daily Return'].plot(legend=True, figsize=(15,5), color='#2a9d8f', linewidth=2)
plt.title(f'Daily Return Percentage of {COMPANY_NAME} Stock', fontsize=15)

plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### MinMaxScaler

# %%
df2 = df.copy(deep=True)

scaler = MinMaxScaler(feature_range=(-1,1))

df2['Open'] = scaler.fit_transform(df2.Open.values.reshape(-1,1))
df2['High'] = scaler.fit_transform(df2.High.values.reshape(-1, 1))
df2['Low'] = scaler.fit_transform(df2.Low.values.reshape(-1, 1))
df2['Close'] = scaler.fit_transform(df2.Close.values.reshape(-1, 1))
df2['Volume'] = scaler.fit_transform(df2.Volume.values.reshape(-1, 1))

df3 = df2[['Open', 'High', 'Low', 'Volume', 'Close']].values

df3.shape
# Out:
# (2264, 5)

# %% [markdown]
# ### Tensorflow Modeling

# %% [markdown]
# #### Preparing Data for time series
# We'll utilize the prices from the previous 10 days to forecast the next day's price. Let's create the sequences accordingly.

# %%
len(df3) - 11 + 1
# Out:
# 2254

# %%
T = 11 # sequence length
sequences = []
for index in range(len(df3) - T + 1):
    sequences.append(df3[index: index + T])

sequences = np.array(sequences)
print(sequences.shape)
# Out:
# (2254, 11, 5)

# %% [markdown]
# #### Splitting the data

# %%
def split_data(sequences):
    df_train, df_test = train_test_split(sequences,
                                         test_size=0.2, shuffle=False)
    df_val, df_test = train_test_split(df_test,
                                        test_size=0.5, shuffle=False)
    return df_train, df_val, df_test

# %%
df_train, df_val, df_test = split_data(sequences)
print('Train shape:', df_train.shape,'Validation shape:', df_val.shape,
      'Test shape:', df_test.shape)
# Out:
# Train shape: (1803, 11, 5) Validation shape: (225, 11, 5) Test shape: (226, 11, 5)

# %%
X_train = df_train[:,:-1,:]
Y_train = df_train[:, -1, -1]

X_valid = df_val[:,:-1,:]
Y_valid = df_val[:, -1, -1]

X_test = df_test[:,:-1,:]
Y_test = df_test[:, -1, -1]

# %% [markdown]
# #### Defining Model

# %%
K = 1
D = df3.shape[1]
T = 10

# %%
i = Input(shape=(T,D))
x = LSTM(64, return_sequences=True)(i)
x = LSTM(128, return_sequences=False)(x)
# x = LSTM(32, return_sequences=False)(x)
x = Dense(50)(x)
x = Dense(K)(x)

model = Model(i,x)

# %%
model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['accuracy']
)

print('Training Model')
r = model.fit(
    X_train,
    Y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_valid, Y_valid)
)
# Out:
# Training Model
# Epoch 1/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.0000e+00 - loss: 0.0347 - val_accuracy: 0.0000e+00 - val_loss: 0.0030
# Epoch 2/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0000e+00 - loss: 9.5064e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0052
# Epoch 3/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0000e+00 - loss: 8.4493e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0041
# Epoch 4/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0000e+00 - loss: 7.8713e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0045
# Epoch 5/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.0000e+00 - loss: 7.6513e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0054
# Epoch 6/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.0000e+00 - loss: 7.6114e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0038
# Epoch 7/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0000e+00 - loss: 7.8471e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0030
# Epoch 8/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.0000e+00 - loss: 6.9366e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0029
# Epoch 9/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 7.4057e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0043
# Epoch 10/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0000e+00 - loss: 7.4406e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0025
# Epoch 11/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.0000e+00 - loss: 6.0511e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0069
# Epoch 12/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.0000e+00 - loss: 7.1792e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0029
# Epoch 13/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.0000e+00 - loss: 6.4102e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 14/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.0000e+00 - loss: 7.9115e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0030
# Epoch 15/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 6.6112e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0019
# Epoch 16/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0000e+00 - loss: 6.2130e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0021
# Epoch 17/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0000e+00 - loss: 6.2628e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0010
# Epoch 18/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0000e+00 - loss: 5.5951e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0021
# Epoch 19/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.0000e+00 - loss: 5.4074e-04 - val_accuracy: 0.0000e+00 - val_loss: 8.8394e-04
# Epoch 20/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.0000e+00 - loss: 5.3557e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 21/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0000e+00 - loss: 5.0281e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 22/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.0000e+00 - loss: 5.7387e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 23/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0000e+00 - loss: 6.3273e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0022
# Epoch 24/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.0000e+00 - loss: 4.9442e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 25/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.0000e+00 - loss: 5.5882e-04 - val_accuracy: 0.0000e+00 - val_loss: 9.0084e-04
# Epoch 26/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 4.4104e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 27/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.0000e+00 - loss: 4.2240e-04 - val_accuracy: 0.0000e+00 - val_loss: 7.0851e-04
# Epoch 28/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.0000e+00 - loss: 4.2055e-04 - val_accuracy: 0.0000e+00 - val_loss: 8.3408e-04
# Epoch 29/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.0000e+00 - loss: 5.3375e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0038
# Epoch 30/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 4.1773e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0033
# Epoch 31/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.0000e+00 - loss: 4.1873e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.6140e-04
# Epoch 32/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.0000e+00 - loss: 3.8668e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 33/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.0000e+00 - loss: 4.1217e-04 - val_accuracy: 0.0000e+00 - val_loss: 8.6719e-04
# Epoch 34/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 4.3250e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.2108e-04
# Epoch 35/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.0000e+00 - loss: 4.2772e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 36/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.0000e+00 - loss: 3.8231e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.3059e-04
# Epoch 37/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.0000e+00 - loss: 3.9810e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0010
# Epoch 38/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.0000e+00 - loss: 3.2289e-04 - val_accuracy: 0.0000e+00 - val_loss: 8.4239e-04
# Epoch 39/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 3.9771e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.1628e-04
# Epoch 40/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0000e+00 - loss: 3.5737e-04 - val_accuracy: 0.0000e+00 - val_loss: 9.3138e-04
# Epoch 41/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0000e+00 - loss: 3.4224e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 42/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.0000e+00 - loss: 2.8866e-04 - val_accuracy: 0.0000e+00 - val_loss: 5.3986e-04
# Epoch 43/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.0000e+00 - loss: 3.0346e-04 - val_accuracy: 0.0000e+00 - val_loss: 5.3797e-04
# Epoch 44/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.0000e+00 - loss: 2.9814e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 45/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 3.4879e-04 - val_accuracy: 0.0000e+00 - val_loss: 7.0418e-04
# Epoch 46/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0000e+00 - loss: 2.7481e-04 - val_accuracy: 0.0000e+00 - val_loss: 7.0893e-04
# Epoch 47/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.0000e+00 - loss: 3.0575e-04 - val_accuracy: 0.0000e+00 - val_loss: 5.9108e-04
# Epoch 48/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 3.3977e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.4540e-04
# Epoch 49/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.0000e+00 - loss: 2.8822e-04 - val_accuracy: 0.0000e+00 - val_loss: 5.6441e-04
# Epoch 50/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.0000e+00 - loss: 3.5386e-04 - val_accuracy: 0.0000e+00 - val_loss: 8.2531e-04

# %%
plt.plot(r.history['loss'], label='Train Loss')
plt.plot(r.history['val_loss'], label='Val Loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='vald accuracy')
plt.legend()

# %%
Y_pred = model.predict(X_test)

test_loss = model.evaluate(X_test, Y_test)
print('Test Loss:', test_loss)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0048 - loss: 0.0015
# Test Loss: [0.0014699308667331934, 0.0044247787445783615]

# %%
plt.figure(figsize=(12,6))
idx = 0
plt.plot(Y_test, color='#2a9d8f', label='Actual')
plt.plot(Y_pred, color='#f4a261', label='Predicted')
plt.xlabel('Time [days]', fontsize=15)
plt.ylabel('Normalized Price', fontsize=15)
plt.title(f'{COMPANY_NAME} Stock Price Prediction Curve')
plt.legend(loc='best', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 10, 5)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 10, 64)              │          17,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 128)                 │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 50)                  │           6,450 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 369,713 (1.41 MB)
#  Trainable params: 123,237 (481.39 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 246,476 (962.80 KB)

# %%
predicted_prices = model.predict(X_test)
df_pred = df.iloc[-len(predicted_prices):].copy()
df_pred['Predicted Close'] = predicted_prices
df_pred['Open'] = df_pred['Open']
df_pred['High'] = df_pred['High']
df_pred['Low'] = df_pred['Low']
df_pred['Close'] = df_pred['Predicted Close']
final_df = df_pred[['Open', 'High', 'Low', 'Close', 'Volume']].copy()

final_df.index = pd.to_datetime(df_pred.index)

mpf.plot(
    final_df,
    type='candle',
    volume=True,
    style='charles',
    title='Predicted Candlestick Chart',
    ylabel = 'Price',
    ylabel_lower = 'Volume',
    figsize=(15,8)
)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
df = df.reset_index()

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

final_df = df[['Open', 'High', 'Low', 'Close']]

candle = go.Candlestick(x=final_df.index, open=final_df['Open'],
                        high=final_df['High'], low=final_df['Low'],
                        close=final_df['Close'], name='Candlestick',
                        increasing_line_color='#2a9d8f',
                        decreasing_line_color='#f4a261'
)

fig = go.Figure([candle])

fig.update_layout(
    title='Predicted Candlestick Chart',
    xaxis_title='Date',
    yaxis_title='Price',
    xaxis_rangeslider_visible=False,
    template='plotly_white',
    height=600,
    width=1000
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1d59dae8-db2e-464b-88cf-a5a1674c63cf" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d59dae8-db2e-464b-88cf-a5a1674c63cf")) {                    Plotly.newPlot(                        "1d59dae8-db2e-464b-88cf-a5a1674c63cf",                        [{"close":[46.5556526184082,45.550079345703125,46.846717834472656,44.97674560546875,44.597434997558594,44.800331115722656,44.526893615722656,46.12343215942383,45.682395935058594,46.01758575439453,45.17961502075195,45.920555114746094,48.59321594238281,48.258033752441406,46.74968719482422,46.008766174316406,45.86763000488281,44.24461364746094,43.583065032958984,43.4683952331543,43.847694396972656,43.83005142211914,44.54452896118164,45.38850021362305,46.570091247558594,46.365753173828125,46.037044525146484,46.7744140625,45.46845626831055,45.62836456298828,46.285797119140625,45.57508087158203,45.20194625854492,46.71223831176758,47.040931701660156,46.50788879394531,46.223602294921875,45.335205078125,45.88600540161133,46.94321823120117,46.241363525390625,47.14753341674805,47.23637008666992,47.60951614379883,48.28470230102539,48.560096740722656,47.52067184448242,47.84938049316406,48.035945892333984,47.947105407714844,48.16032028198242,47.56509017944336,48.60452651977539,48.90659713745117,49.06648254394531,49.36854553222656,49.24416732788086,48.47126388549805,48.96876525878906,48.38241195678711,48.34688949584961,48.24916458129883,48.55123519897461,49.17310333251953,49.18197250366211,49.43963623046875,50.15922546386719,50.09703826904297,49.38631820678711,49.555118560791016,46.00151443481445,46.29468536376953,45.6994514465332,45.255245208740234,44.33131790161133,44.304656982421875,44.962066650390625,44.224693298339844,44.304656982421875,44.366844177246094,44.76662063598633,44.48234558105469,45.326316833496094,45.35296630859375,45.76164245605469,45.37963104248047,46.045928955078125,45.18709182739258,45.45547866821289,45.017112731933594,45.285499572753906,44.75768280029297,46.153282165527344,46.627418518066406,46.42165756225586,46.80634689331055,47.414676666259766,47.280494689941406,46.94947814941406,46.33220291137695,46.636375427246094,46.609535217285156,46.55585479736328,46.180118560791016,46.054866790771484,44.85608673095703,44.578758239746094,44.45351028442383,45.079734802246094,44.847145080566406,44.79347229003906,45.795433044433594,45.616519927978516,46.43954849243164,44.578758239746094,43.3262825012207,44.22985076904297,45.21392059326172,45.77753448486328,45.76858139038086,45.77753448486328,45.96541213989258,45.96541213989258,46.788455963134766,47.047889709472656,47.60255813598633,47.870948791503906,48.076717376708984,48.04093551635742,48.27350616455078,47.49519348144531,50.01802062988281,49.91960906982422,50.608463287353516,50.75160217285156,50.778446197509766,50.26851272583008,50.286399841308594,50.70686721801758,50.617408752441406,50.617408752441406,50.9663200378418,51.3420524597168,51.851993560791016,51.94145584106445,52.06669616699219,51.90565872192383,52.156158447265625,51.83409881591797,51.99512481689453,51.707061767578125,51.81509780883789,51.851097106933594,51.86909103393555,51.91410827636719,52.112144470214844,52.166160583496094,52.36419677734375,52.2381706237793,52.301185607910156,52.112144470214844,51.72507095336914,51.84209060668945,51.91410827636719,51.86009216308594,51.90511703491211,51.698062896728516,50.599815368652344,51.35599899291992,50.88788986206055,50.64482498168945,51.48202133178711,51.53602600097656,51.247962951660156,51.13994598388672,51.99512481689453,52.049129486083984,51.698062896728516,51.2209587097168,52.166160583496094,52.2381706237793,51.67106246948242,51.851097106933594,51.689056396484375,51.52702331542969,51.88710021972656,51.97713088989258,52 ...

# %%
latest_preds = []
last_seq = X_test[:-1]

for i in range(10):
    prediction = model.predict(last_seq)
    latest_preds.append(prediction)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
df = df.reset_index()

# %%
predicted_data_next = np.array(latest_preds).reshape(-1,5)
last_date = df['Date'].max()

next_10_days = [last_date + timedelta(days=i) for i in range(1,11)]

for i, feature_name in enumerate(['Open','High','Low','Volume','Close']):
    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=next_10_days,
        y=predicted_data_next[:,i],
        mode='lines+markers',
        name=f'Predicted {feature_name.capitalize()} Prices',
        line=dict(color='#f4a261'),
        marker=dict(color='#f4a261')
    ))

    fig.update_layout(
        title=f'Predicted {feature_name.capitalize()} Prices for the next 10 days',
        xaxis_title='Date',
        yaxis_title=f'{feature_name.capitalize()} Price',
        plot_bgcolor='White'
    )
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bbfa551f-af1d-437d-a9c0-92be4b20396c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbfa551f-af1d-437d-a9c0-92be4b20396c")) {                    Plotly.newPlot(                        "bbfa551f-af1d-437d-a9c0-92be4b20396c",                        [{"line":{"color":"#f4a261"},"marker":{"color":"#f4a261"},"mode":"lines+markers","name":"Predicted Open Prices","x":["2025-01-11T00:00:00-05:00","2025-01-12T00:00:00-05:00","2025-01-13T00:00:00-05:00","2025-01-14T00:00:00-05:00","2025-01-15T00:00:00-05:00","2025-01-16T00:00:00-05:00","2025-01-17T00:00:00-05:00","2025-01-18T00:00:00-05:00","2025-01-19T00:00:00-05:00","2025-01-20T00:00:00-05:00"],"y":[0.68008465,0.7238494,0.7320907,0.6910407,0.7432634,0.7857912,0.77140456,0.7746343,0.72981906,0.6544542,0.68208784,0.7194655,0.71747047,0.76854694,0.7866069,0.7320181,0.79804623,0.87734956,0.892596,0.93896943,0.9082721,0.82857645,0.738428,0.75377095,0.6735822,0.7594789,0.7402584,0.73173136,0.6756154,0.8130404,0.81967443,0.7873534,0.7357593,0.73431283,0.7450925,0.7963881,0.7068396,0.7825907,0.74033374,0.7331084,0.792607,0.8751932,0.8876714,0.8435754,0.75233316,0.68008465,0.7238494,0.7320907,0.6910407,0.7432634,0.7857912,0.77140456,0.7746343,0.72981906,0.6544542,0.68208784,0.7194655,0.71747047,0.76854694,0.7866069,0.7320181,0.79804623,0.87734956,0.892596,0.93896943,0.9082721,0.82857645,0.738428,0.75377095,0.6735822,0.7594789,0.7402584,0.73173136,0.6756154,0.8130404,0.81967443,0.7873534,0.7357593,0.73431283,0.7450925,0.7963881,0.7068396,0.7825907,0.74033374,0.7331084,0.792607,0.8751932,0.8876714,0.8435754,0.75233316,0.68008465,0.7238494,0.7320907,0.6910407,0.7432634,0.7857912,0.77140456,0.7746343,0.72981906,0.6544542,0.68208784,0.7194655,0.71747047,0.76854694,0.7866069,0.7320181,0.79804623,0.87734956,0.892596,0.93896943,0.9082721,0.82857645,0.738428,0.75377095,0.6735822,0.7594789,0.7402584,0.73173136,0.6756154,0.8130404,0.81967443,0.7873534,0.7357593,0.73431283,0.7450925,0.7963881,0.7068396,0.7825907,0.74033374,0.7331084,0.792607,0.8751932,0.8876714,0.8435754,0.75233316,0.68008465,0.7238494,0.7320907,0.6910407,0.7432634,0.7857912,0.77140456,0.7746343,0.72981906,0.6544542,0.68208784,0.7194655,0.71747047,0.76854694,0.7866069,0.7320181,0.79804623,0.87734956,0.892596,0.93896943,0.9082721,0.82857645,0.738428,0.75377095,0.6735822,0.7594789,0.7402584,0.73173136,0.6756154,0.8130404,0.81967443,0.7873534,0.7357593,0.73431283,0.7450925,0.7963881,0.7068396,0.7825907,0.74033374,0.7331084,0.792607,0.8751932,0.8876714,0.8435754,0.75233316,0.68008465,0.7238494,0.7320907,0.6910407,0.7432634,0.7857912,0.77140456,0.7746343,0.72981906,0.6544542,0.68208784,0.7194655,0.71747047,0.76854694,0.7866069,0.7320181,0.79804623,0.87734956,0.892596,0.93896943,0.9082721,0.82857645,0.738428,0.75377095,0.6735822,0.7594789,0.7402584,0.73173136,0.6756154,0.8130404,0.81967443,0.7873534,0.7357593,0.73431283,0.7450925,0.7963881,0.7068396,0.7825907,0.74033374,0.7331084,0.792607,0.8751932,0.8876714,0.8435754,0.75233316,0.68008465,0.7238494,0.7320907,0.6910407,0.7432634,0.7857912,0.77140456,0.7746343,0.72981906,0.6544542,0.68208784,0.7194655,0.71747047,0.76854694,0.7866069,0.7320181,0.79804623,0.87734956,0.892596,0.93896943,0.9082721,0.82857645,0.738428,0.75377095,0.6735822,0.7594789,0.7402584,0.73173136,0.6756154,0.8130404,0.81967443,0.7873534,0.7357593,0.73431283,0.7450925,0.7963881,0.7068396,0.7825907,0.74033374,0.7331084,0.792607,0.8751932,0.8876714,0.8435754,0.75233316,0.68008465,0.7238494,0.7320907,0.6910407,0.7432634,0.7857912,0.77140456,0.7746343,0.72981906,0.6544542,0.68208784,0.7194655,0.71747047,0.76854694,0.7866069,0.7320181,0.79804623,0.87734956,0.892596,0.93896943,0.9082721,0.82857645,0.738428,0.75377095,0.67358 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f00fdd33-5c4f-4e3d-ae38-c4664137f078" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f00fdd33-5c4f-4e3d-ae38-c4664137f078")) {                    Plotly.newPlot(                        "f00fdd33-5c4f-4e3d-ae38-c4664137f078",                        [{"line":{"color":"#f4a261"},"marker":{"color":"#f4a261"},"mode":"lines+markers","name":"Predicted High Prices","x":["2025-01-11T00:00:00-05:00","2025-01-12T00:00:00-05:00","2025-01-13T00:00:00-05:00","2025-01-14T00:00:00-05:00","2025-01-15T00:00:00-05:00","2025-01-16T00:00:00-05:00","2025-01-17T00:00:00-05:00","2025-01-18T00:00:00-05:00","2025-01-19T00:00:00-05:00","2025-01-20T00:00:00-05:00"],"y":[0.67517364,0.70131975,0.73333865,0.67358696,0.7480423,0.7579888,0.75190616,0.7723315,0.72040707,0.6932074,0.6207632,0.7138105,0.72375906,0.7937797,0.78655887,0.76456296,0.8430098,0.8581673,0.9031972,0.957314,0.89336807,0.8214631,0.75691473,0.7076273,0.68614525,0.75347966,0.72359365,0.7381798,0.6833795,0.81341314,0.8335931,0.7852564,0.714426,0.75691116,0.74209845,0.7920844,0.69856846,0.74746746,0.727213,0.7523055,0.8083592,0.8690382,0.91008633,0.8536878,0.74159145,0.67517364,0.70131975,0.73333865,0.67358696,0.7480423,0.7579888,0.75190616,0.7723315,0.72040707,0.6932074,0.6207632,0.7138105,0.72375906,0.7937797,0.78655887,0.76456296,0.8430098,0.8581673,0.9031972,0.957314,0.89336807,0.8214631,0.75691473,0.7076273,0.68614525,0.75347966,0.72359365,0.7381798,0.6833795,0.81341314,0.8335931,0.7852564,0.714426,0.75691116,0.74209845,0.7920844,0.69856846,0.74746746,0.727213,0.7523055,0.8083592,0.8690382,0.91008633,0.8536878,0.74159145,0.67517364,0.70131975,0.73333865,0.67358696,0.7480423,0.7579888,0.75190616,0.7723315,0.72040707,0.6932074,0.6207632,0.7138105,0.72375906,0.7937797,0.78655887,0.76456296,0.8430098,0.8581673,0.9031972,0.957314,0.89336807,0.8214631,0.75691473,0.7076273,0.68614525,0.75347966,0.72359365,0.7381798,0.6833795,0.81341314,0.8335931,0.7852564,0.714426,0.75691116,0.74209845,0.7920844,0.69856846,0.74746746,0.727213,0.7523055,0.8083592,0.8690382,0.91008633,0.8536878,0.74159145,0.67517364,0.70131975,0.73333865,0.67358696,0.7480423,0.7579888,0.75190616,0.7723315,0.72040707,0.6932074,0.6207632,0.7138105,0.72375906,0.7937797,0.78655887,0.76456296,0.8430098,0.8581673,0.9031972,0.957314,0.89336807,0.8214631,0.75691473,0.7076273,0.68614525,0.75347966,0.72359365,0.7381798,0.6833795,0.81341314,0.8335931,0.7852564,0.714426,0.75691116,0.74209845,0.7920844,0.69856846,0.74746746,0.727213,0.7523055,0.8083592,0.8690382,0.91008633,0.8536878,0.74159145,0.67517364,0.70131975,0.73333865,0.67358696,0.7480423,0.7579888,0.75190616,0.7723315,0.72040707,0.6932074,0.6207632,0.7138105,0.72375906,0.7937797,0.78655887,0.76456296,0.8430098,0.8581673,0.9031972,0.957314,0.89336807,0.8214631,0.75691473,0.7076273,0.68614525,0.75347966,0.72359365,0.7381798,0.6833795,0.81341314,0.8335931,0.7852564,0.714426,0.75691116,0.74209845,0.7920844,0.69856846,0.74746746,0.727213,0.7523055,0.8083592,0.8690382,0.91008633,0.8536878,0.74159145,0.67517364,0.70131975,0.73333865,0.67358696,0.7480423,0.7579888,0.75190616,0.7723315,0.72040707,0.6932074,0.6207632,0.7138105,0.72375906,0.7937797,0.78655887,0.76456296,0.8430098,0.8581673,0.9031972,0.957314,0.89336807,0.8214631,0.75691473,0.7076273,0.68614525,0.75347966,0.72359365,0.7381798,0.6833795,0.81341314,0.8335931,0.7852564,0.714426,0.75691116,0.74209845,0.7920844,0.69856846,0.74746746,0.727213,0.7523055,0.8083592,0.8690382,0.91008633,0.8536878,0.74159145,0.67517364,0.70131975,0.73333865,0.67358696,0.7480423,0.7579888,0.75190616,0.7723315,0.72040707,0.6932074,0.6207632,0.7138105,0.72375906,0.7937797,0.78655887,0.76456296,0.8430098,0.8581673,0.9031972,0.957314,0.89336807,0.82146 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="602feb39-5ef4-48fa-aa03-12845e975a9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("602feb39-5ef4-48fa-aa03-12845e975a9f")) {                    Plotly.newPlot(                        "602feb39-5ef4-48fa-aa03-12845e975a9f",                        [{"line":{"color":"#f4a261"},"marker":{"color":"#f4a261"},"mode":"lines+markers","name":"Predicted Low Prices","x":["2025-01-11T00:00:00-05:00","2025-01-12T00:00:00-05:00","2025-01-13T00:00:00-05:00","2025-01-14T00:00:00-05:00","2025-01-15T00:00:00-05:00","2025-01-16T00:00:00-05:00","2025-01-17T00:00:00-05:00","2025-01-18T00:00:00-05:00","2025-01-19T00:00:00-05:00","2025-01-20T00:00:00-05:00"],"y":[0.6584826,0.67969203,0.6759354,0.7134453,0.74795496,0.748444,0.75036776,0.7532048,0.7124142,0.71221757,0.62751645,0.7028956,0.75978667,0.8031122,0.7259429,0.7764453,0.86228114,0.8750543,0.87543684,0.964398,0.89959514,0.854467,0.79091746,0.620802,0.69198805,0.7562306,0.7181105,0.7232018,0.7253088,0.8291591,0.7985174,0.75610733,0.7217066,0.74997306,0.78173417,0.7987395,0.7139948,0.7554388,0.7318863,0.79427415,0.83607024,0.88069874,0.85485995,0.84194046,0.7643778,0.6584826,0.67969203,0.6759354,0.7134453,0.74795496,0.748444,0.75036776,0.7532048,0.7124142,0.71221757,0.62751645,0.7028956,0.75978667,0.8031122,0.7259429,0.7764453,0.86228114,0.8750543,0.87543684,0.964398,0.89959514,0.854467,0.79091746,0.620802,0.69198805,0.7562306,0.7181105,0.7232018,0.7253088,0.8291591,0.7985174,0.75610733,0.7217066,0.74997306,0.78173417,0.7987395,0.7139948,0.7554388,0.7318863,0.79427415,0.83607024,0.88069874,0.85485995,0.84194046,0.7643778,0.6584826,0.67969203,0.6759354,0.7134453,0.74795496,0.748444,0.75036776,0.7532048,0.7124142,0.71221757,0.62751645,0.7028956,0.75978667,0.8031122,0.7259429,0.7764453,0.86228114,0.8750543,0.87543684,0.964398,0.89959514,0.854467,0.79091746,0.620802,0.69198805,0.7562306,0.7181105,0.7232018,0.7253088,0.8291591,0.7985174,0.75610733,0.7217066,0.74997306,0.78173417,0.7987395,0.7139948,0.7554388,0.7318863,0.79427415,0.83607024,0.88069874,0.85485995,0.84194046,0.7643778,0.6584826,0.67969203,0.6759354,0.7134453,0.74795496,0.748444,0.75036776,0.7532048,0.7124142,0.71221757,0.62751645,0.7028956,0.75978667,0.8031122,0.7259429,0.7764453,0.86228114,0.8750543,0.87543684,0.964398,0.89959514,0.854467,0.79091746,0.620802,0.69198805,0.7562306,0.7181105,0.7232018,0.7253088,0.8291591,0.7985174,0.75610733,0.7217066,0.74997306,0.78173417,0.7987395,0.7139948,0.7554388,0.7318863,0.79427415,0.83607024,0.88069874,0.85485995,0.84194046,0.7643778,0.6584826,0.67969203,0.6759354,0.7134453,0.74795496,0.748444,0.75036776,0.7532048,0.7124142,0.71221757,0.62751645,0.7028956,0.75978667,0.8031122,0.7259429,0.7764453,0.86228114,0.8750543,0.87543684,0.964398,0.89959514,0.854467,0.79091746,0.620802,0.69198805,0.7562306,0.7181105,0.7232018,0.7253088,0.8291591,0.7985174,0.75610733,0.7217066,0.74997306,0.78173417,0.7987395,0.7139948,0.7554388,0.7318863,0.79427415,0.83607024,0.88069874,0.85485995,0.84194046,0.7643778,0.6584826,0.67969203,0.6759354,0.7134453,0.74795496,0.748444,0.75036776,0.7532048,0.7124142,0.71221757,0.62751645,0.7028956,0.75978667,0.8031122,0.7259429,0.7764453,0.86228114,0.8750543,0.87543684,0.964398,0.89959514,0.854467,0.79091746,0.620802,0.69198805,0.7562306,0.7181105,0.7232018,0.7253088,0.8291591,0.7985174,0.75610733,0.7217066,0.74997306,0.78173417,0.7987395,0.7139948,0.7554388,0.7318863,0.79427415,0.83607024,0.88069874,0.85485995,0.84194046,0.7643778,0.6584826,0.67969203,0.6759354,0.7134453,0.74795496,0.748444,0.75036776,0.7532048,0.7124142,0.71221757,0.62751645,0.7028956,0.75978667,0.8031122,0.7259429,0.7764453,0.86228114,0.8750543,0.87543684,0.964398,0.89959514,0.854467,0.79091746,0.620802 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c36d3a85-4143-42c6-9e7a-eee59601a8e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c36d3a85-4143-42c6-9e7a-eee59601a8e3")) {                    Plotly.newPlot(                        "c36d3a85-4143-42c6-9e7a-eee59601a8e3",                        [{"line":{"color":"#f4a261"},"marker":{"color":"#f4a261"},"mode":"lines+markers","name":"Predicted Volume Prices","x":["2025-01-11T00:00:00-05:00","2025-01-12T00:00:00-05:00","2025-01-13T00:00:00-05:00","2025-01-14T00:00:00-05:00","2025-01-15T00:00:00-05:00","2025-01-16T00:00:00-05:00","2025-01-17T00:00:00-05:00","2025-01-18T00:00:00-05:00","2025-01-19T00:00:00-05:00","2025-01-20T00:00:00-05:00"],"y":[0.65588427,0.68287265,0.65364236,0.7344627,0.76536494,0.74310523,0.7506481,0.77410316,0.6773067,0.6323187,0.6446048,0.7034765,0.7719412,0.7908591,0.69319546,0.7746842,0.8516957,0.89326316,0.9011342,0.9317497,0.8798721,0.8769098,0.76315117,0.6554787,0.72100013,0.7733371,0.7140649,0.70095336,0.76347315,0.8085593,0.7982681,0.7385139,0.75089145,0.7254621,0.7942198,0.8183021,0.7415106,0.7708362,0.7241967,0.7901614,0.8649948,0.90192175,0.8286473,0.7880878,0.8092383,0.65588427,0.68287265,0.65364236,0.7344627,0.76536494,0.74310523,0.7506481,0.77410316,0.6773067,0.6323187,0.6446048,0.7034765,0.7719412,0.7908591,0.69319546,0.7746842,0.8516957,0.89326316,0.9011342,0.9317497,0.8798721,0.8769098,0.76315117,0.6554787,0.72100013,0.7733371,0.7140649,0.70095336,0.76347315,0.8085593,0.7982681,0.7385139,0.75089145,0.7254621,0.7942198,0.8183021,0.7415106,0.7708362,0.7241967,0.7901614,0.8649948,0.90192175,0.8286473,0.7880878,0.8092383,0.65588427,0.68287265,0.65364236,0.7344627,0.76536494,0.74310523,0.7506481,0.77410316,0.6773067,0.6323187,0.6446048,0.7034765,0.7719412,0.7908591,0.69319546,0.7746842,0.8516957,0.89326316,0.9011342,0.9317497,0.8798721,0.8769098,0.76315117,0.6554787,0.72100013,0.7733371,0.7140649,0.70095336,0.76347315,0.8085593,0.7982681,0.7385139,0.75089145,0.7254621,0.7942198,0.8183021,0.7415106,0.7708362,0.7241967,0.7901614,0.8649948,0.90192175,0.8286473,0.7880878,0.8092383,0.65588427,0.68287265,0.65364236,0.7344627,0.76536494,0.74310523,0.7506481,0.77410316,0.6773067,0.6323187,0.6446048,0.7034765,0.7719412,0.7908591,0.69319546,0.7746842,0.8516957,0.89326316,0.9011342,0.9317497,0.8798721,0.8769098,0.76315117,0.6554787,0.72100013,0.7733371,0.7140649,0.70095336,0.76347315,0.8085593,0.7982681,0.7385139,0.75089145,0.7254621,0.7942198,0.8183021,0.7415106,0.7708362,0.7241967,0.7901614,0.8649948,0.90192175,0.8286473,0.7880878,0.8092383,0.65588427,0.68287265,0.65364236,0.7344627,0.76536494,0.74310523,0.7506481,0.77410316,0.6773067,0.6323187,0.6446048,0.7034765,0.7719412,0.7908591,0.69319546,0.7746842,0.8516957,0.89326316,0.9011342,0.9317497,0.8798721,0.8769098,0.76315117,0.6554787,0.72100013,0.7733371,0.7140649,0.70095336,0.76347315,0.8085593,0.7982681,0.7385139,0.75089145,0.7254621,0.7942198,0.8183021,0.7415106,0.7708362,0.7241967,0.7901614,0.8649948,0.90192175,0.8286473,0.7880878,0.8092383,0.65588427,0.68287265,0.65364236,0.7344627,0.76536494,0.74310523,0.7506481,0.77410316,0.6773067,0.6323187,0.6446048,0.7034765,0.7719412,0.7908591,0.69319546,0.7746842,0.8516957,0.89326316,0.9011342,0.9317497,0.8798721,0.8769098,0.76315117,0.6554787,0.72100013,0.7733371,0.7140649,0.70095336,0.76347315,0.8085593,0.7982681,0.7385139,0.75089145,0.7254621,0.7942198,0.8183021,0.7415106,0.7708362,0.7241967,0.7901614,0.8649948,0.90192175,0.8286473,0.7880878,0.8092383,0.65588427,0.68287265,0.65364236,0.7344627,0.76536494,0.74310523,0.7506481,0.77410316,0.6773067,0.6323187,0.6446048,0.7034765,0.7719412,0.7908591,0.69319546,0.7746842,0.8516957,0.89326316,0.9011342,0.9317497,0.8798721,0.8769098,0.76315117,0.6554787 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cb2c647f-b4e7-4e38-a079-ecdf464165cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb2c647f-b4e7-4e38-a079-ecdf464165cd")) {                    Plotly.newPlot(                        "cb2c647f-b4e7-4e38-a079-ecdf464165cd",                        [{"line":{"color":"#f4a261"},"marker":{"color":"#f4a261"},"mode":"lines+markers","name":"Predicted Close Prices","x":["2025-01-11T00:00:00-05:00","2025-01-12T00:00:00-05:00","2025-01-13T00:00:00-05:00","2025-01-14T00:00:00-05:00","2025-01-15T00:00:00-05:00","2025-01-16T00:00:00-05:00","2025-01-17T00:00:00-05:00","2025-01-18T00:00:00-05:00","2025-01-19T00:00:00-05:00","2025-01-20T00:00:00-05:00"],"y":[0.7073355,0.7008456,0.6839791,0.77108026,0.78870356,0.74116653,0.76453495,0.75719917,0.64808977,0.69483584,0.6858162,0.71702516,0.75586104,0.78672934,0.72431976,0.780441,0.87127244,0.8892184,0.9276715,0.94058895,0.8405246,0.8004215,0.73474675,0.6696132,0.73800856,0.77245635,0.70615584,0.70244783,0.79408294,0.8370375,0.80046093,0.73234445,0.74089646,0.7420662,0.78122234,0.69523376,0.7860778,0.77535784,0.725587,0.7679307,0.8768401,0.885008,0.80568963,0.75808746,0.791156,0.7073355,0.7008456,0.6839791,0.77108026,0.78870356,0.74116653,0.76453495,0.75719917,0.64808977,0.69483584,0.6858162,0.71702516,0.75586104,0.78672934,0.72431976,0.780441,0.87127244,0.8892184,0.9276715,0.94058895,0.8405246,0.8004215,0.73474675,0.6696132,0.73800856,0.77245635,0.70615584,0.70244783,0.79408294,0.8370375,0.80046093,0.73234445,0.74089646,0.7420662,0.78122234,0.69523376,0.7860778,0.77535784,0.725587,0.7679307,0.8768401,0.885008,0.80568963,0.75808746,0.791156,0.7073355,0.7008456,0.6839791,0.77108026,0.78870356,0.74116653,0.76453495,0.75719917,0.64808977,0.69483584,0.6858162,0.71702516,0.75586104,0.78672934,0.72431976,0.780441,0.87127244,0.8892184,0.9276715,0.94058895,0.8405246,0.8004215,0.73474675,0.6696132,0.73800856,0.77245635,0.70615584,0.70244783,0.79408294,0.8370375,0.80046093,0.73234445,0.74089646,0.7420662,0.78122234,0.69523376,0.7860778,0.77535784,0.725587,0.7679307,0.8768401,0.885008,0.80568963,0.75808746,0.791156,0.7073355,0.7008456,0.6839791,0.77108026,0.78870356,0.74116653,0.76453495,0.75719917,0.64808977,0.69483584,0.6858162,0.71702516,0.75586104,0.78672934,0.72431976,0.780441,0.87127244,0.8892184,0.9276715,0.94058895,0.8405246,0.8004215,0.73474675,0.6696132,0.73800856,0.77245635,0.70615584,0.70244783,0.79408294,0.8370375,0.80046093,0.73234445,0.74089646,0.7420662,0.78122234,0.69523376,0.7860778,0.77535784,0.725587,0.7679307,0.8768401,0.885008,0.80568963,0.75808746,0.791156,0.7073355,0.7008456,0.6839791,0.77108026,0.78870356,0.74116653,0.76453495,0.75719917,0.64808977,0.69483584,0.6858162,0.71702516,0.75586104,0.78672934,0.72431976,0.780441,0.87127244,0.8892184,0.9276715,0.94058895,0.8405246,0.8004215,0.73474675,0.6696132,0.73800856,0.77245635,0.70615584,0.70244783,0.79408294,0.8370375,0.80046093,0.73234445,0.74089646,0.7420662,0.78122234,0.69523376,0.7860778,0.77535784,0.725587,0.7679307,0.8768401,0.885008,0.80568963,0.75808746,0.791156,0.7073355,0.7008456,0.6839791,0.77108026,0.78870356,0.74116653,0.76453495,0.75719917,0.64808977,0.69483584,0.6858162,0.71702516,0.75586104,0.78672934,0.72431976,0.780441,0.87127244,0.8892184,0.9276715,0.94058895,0.8405246,0.8004215,0.73474675,0.6696132,0.73800856,0.77245635,0.70615584,0.70244783,0.79408294,0.8370375,0.80046093,0.73234445,0.74089646,0.7420662,0.78122234,0.69523376,0.7860778,0.77535784,0.725587,0.7679307,0.8768401,0.885008,0.80568963,0.75808746,0.791156,0.7073355,0.7008456,0.6839791,0.77108026,0.78870356,0.74116653,0.76453495,0.75719917,0.64808977,0.69483584,0.6858162,0.71702516,0.75586104,0.78672934,0.72431976,0.780441,0.87127244,0.8892184,0.92 ...
