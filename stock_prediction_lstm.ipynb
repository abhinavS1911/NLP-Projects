# %%
# ! pip install mplfinance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import math

import yfinance as yf
import datetime as dt
from datetime import timedelta
import mplfinance as mpf

import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Bidirectional
from tensorflow.keras.layers import LSTM, Embedding, SpatialDropout1D, Dropout
from tensorflow.keras.models import Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
COMPANY_NAME = "AAPL"

# %%
company_ticker = yf.Ticker(COMPANY_NAME)

df = company_ticker.history(start='2016-01-12', end=None)
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2016-01-12 00:00:00-05:00   22.773440   22.805148   22.386143   22.639811
# 2016-01-13 00:00:00-05:00   22.721344   22.918389   22.037348   22.057732
# 2016-01-14 00:00:00-05:00   22.186834   22.757586   21.684028   22.540155
# 2016-01-15 00:00:00-05:00   21.788202   22.130200   21.597952   21.998837
# 2016-01-19 00:00:00-05:00   22.288754   22.343111   21.629671   21.892399
# ...                               ...         ...         ...         ...
# 2025-01-06 00:00:00-05:00  244.309998  247.330002  243.199997  245.000000
# 2025-01-07 00:00:00-05:00  242.979996  245.550003  241.350006  242.210007
# 2025-01-08 00:00:00-05:00  241.919998  243.710007  240.050003  242.699997
# 2025-01-10 00:00:00-05:00  240.009995  240.160004  233.000000  236.850006
# 2025-01-13 00:00:00-05:00  233.500000  233.589996  229.720001  232.320007
#
#                               Volume  Dividends  Stock Splits
# Date
# 2016-01-12 00:00:00-05:00  196616800        0.0           0.0
# 2016-01-13 00:00:00-05:00  249758400        0.0           0.0
# 2016-01-14 00:00:00-05:00  252680400        0.0           0.0
# 2016-01-15 00:00:00-05:00  319335600        0.0           0.0
# 2016-01-19 00:00:00-05:00  212350800        0.0           0.0
# ...                              ...        ...           ...
# 2025-01-06 00:00:00-05:00   45045600        0.0           0.0
# 2025-01-07 00:00:00-05:00   40856000        0.0           0.0
# 2025-01-08 00:00:00-05:00   37628900        0.0           0.0
# 2025-01-10 00:00:00-05:00   61679400        0.0           0.0
# 2025-01-13 00:00:00-05:00   22652583        0.0           0.0
#
# [2265 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
df.shape
# Out:
# (2265, 7)

# %%
df['Volume'] = df['Volume'].astype('float64')

# %%
# Returns True if there are duplicate rows
has_duplicates = df.duplicated().any()

print(has_duplicates)
# Out:
# False

# %%
has_nan = df.isna().any().any()

print(has_nan)  # Returns True if there are any NaN values
# Out:
# False

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2265.000000  2265.000000  2265.000000  2265.000000  2.265000e+03
# mean    102.318990   103.409373   101.308033   102.415853  1.064264e+08
# std      65.375848    66.032335    64.763005    65.441047  5.777185e+07
# min      20.619369    21.001973    20.497944    20.697264  2.265258e+07
# 25%      40.791172    41.112512    40.559657    40.817535  6.816940e+07
# 50%      91.770306    92.793440    91.088236    92.384201  9.372830e+07
# 75%     158.159254   160.618383   156.445849   158.424896  1.288284e+08
# max     258.190002   260.100006   257.630005   259.019989  5.334788e+08
#
#          Dividends  Stock Splits
# count  2265.000000   2265.000000
# mean      0.003161      0.001766
# std       0.025284      0.084048
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       0.250000      4.000000

# %%
# finding unique data
df.apply(lambda x: len(x.unique()))
# Out:
# Open            2263
# High            2264
# Low             2265
# Close           2234
# Volume          2258
# Dividends         11
# Stock Splits       2
# dtype: int64

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues',
            linewidths=.6 , cbar = False)
plt.title('Analysis of Coorelations', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
plt.show()

# %%
columns=['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']

# %%
palette = "GnBu"
for column in columns:
    plt.figure(figsize=(20,6))
    sns.boxplot(x=df[column], palette=palette)
    plt.title(f'Distribution of {column}', fontsize=15)
    plt.xlabel(column, fontsize=15)
    stats = df[column].describe()
    stats_text = "\n".join([f'{key}: {value:.2f}' for key, value in stats.items()])
    plt.text(0.95,0.95, stats_text, transform=plt.gca().transAxes,
             fontsize=10, verticalalignment='top', horizontalalignment='center',
             bbox=dict(boxstyle='round, pad=0.2', edgecolor='black',facecolor='#f4a261'))
    plt.grid(True)
    plt.show()

# %%
x = df.index
colors = ['#264653', '#2a9d8f', '#f4a261', '#e76f51','#e9c46a', '#e9d8a6']
plt.figure(figsize=(28,10))
plt.subplot(3,2,1)
plt.plot(x, df['Open'], color=colors[0], linewidth=2)
plt.title('Open', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3,2,2)
plt.plot(x,df['High'], color=colors[1], linewidth=2)
plt.title('High', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3,2,3)
plt.plot(x, df['Low'], color=colors[2], linewidth=2)
plt.title('Low', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3,2,4)
plt.plot(x, df['Close'], color=colors[3], linewidth=2)
plt.title('Close', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 5)
plt.plot(x, df['Volume'], color=colors[4], linewidth=2)
plt.title('Volume', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 6)
plt.plot(x, df['Dividends'], color=colors[5], linewidth=2)
plt.title('Dividends', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.suptitle(f'{COMPANY_NAME} Stock Attributes from 2016 to 2024', fontsize=22, y=0.98)
plt.tight_layout()
plt.show()

# %%
colors = ['#264653', '#2a9d8f', '#f4a261', '#e76f51', '#e9c46a', '#e9d8a6']

df_weekly = df.asfreq('W', method='ffill')
df_weekly.plot(subplots=True, figsize=(15,15), style='-', color=colors, linewidth=2)
plt.suptitle(f"{COMPANY_NAME} Stock Weekly Frequency Attributes", fontsize=20, y=0.95)

for ax in plt.gcf().get_axes():
    ax.grid(True, linestyle='--', alpha=0.5)
    ax.set_title(ax.get_title(), fontsize=14)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
colors = ['#264653', '#2a9d8f', '#f4a261', '#e76f51', '#e9c46a', '#e9d8a6']
df_weekly = df.asfreq('M', method='ffill')
df_weekly.plot(subplots=True, figsize=(15, 15), style='-', color=colors, linewidth=2)
plt.suptitle(f'{COMPANY_NAME} Stock Attributes Over Time (Monthly Frequency)', fontsize=20, y=0.95)
for ax in plt.gcf().get_axes():
    ax.grid(True, linestyle='--', alpha=0.5)
    ax.set_title(ax.get_title(), fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Candlestick char
candle = go.Candlestick(x=df.index, open=df['Open'],
                        high=df['High'], low=df['Low'],
                        close=df['Close'],name='Candlestick',
                        increasing=dict(line=dict(color='#2a9d8f')),
                        decreasing=dict(line=dict(color='#f4a261')))

layout = go.Layout(title=f'{COMPANY_NAME} Candlestick Chart',
                   xaxis=dict(title='Date', color='#2a9d8f'),
                   yaxis=dict(title='Price', color='#2a9d8f',rangemode='normal'),
                   plot_bgcolor='rgba(0,0,0,0)',
                   paper_bgcolor='rgba(255,255,255,0.85)')

fig = go.Figure(data=[candle], layout=layout)

# fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cde1c55e-9a67-4e35-b7ef-940cc37d8468" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c
 2014 to 2025', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Mean Close Price', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['High'].resample('A').mean().plot(kind='bar', color='#005f73')
plt.title('Yearly Mean High from 2014 to 2024', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Mean High Price', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['Low'].resample('A').mean().plot(kind='bar', color='#ee9b00')
plt.title('Yearly Mean Low from 2016 to 2024', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Mean Low Price', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df1 = df.copy()
df1.drop("Stock Splits", axis=1, inplace=True)
fig = plt.figure(figsize = (20,10))
ax = fig.gca()
hist=df1.hist(ax = ax , color= '#2a9d8f')

# %% [markdown]
# ### SMA (Simple Moving Average)

# %%
md = [10, 20, 50]

for SMA in md:
    col = f'SMA for {SMA} days'
    df[col] = df['Close'].rolling(SMA).mean()

df[['Close', 'SMA for 10 days', 'SMA for 20 days', 'SMA for 50 days']].plot(figsize=(15,5))
plt.title('Comparison between SMA and Close Price', fontsize=15)
plt.show()

# %%
df['Daily Return'] = df['Close'].pct_change()
df['Daily Return'].plot(legend=True, figsize=(15,5), color='#2a9d8f', linewidth=2)
plt.title(f'Daily Return Percentage of {COMPANY_NAME} Stock', fontsize=15)

plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### MinMaxScaler

# %%
df2 = df.copy(deep=True)

scaler = MinMaxScaler(feature_range=(-1,1))

df2['Open'] = scaler.fit_transform(df2.Open.values.reshape(-1,1))
df2['High'] = scaler.fit_transform(df2.High.values.reshape(-1, 1))
df2['Low'] = scaler.fit_transform(df2.Low.values.reshape(-1, 1))
df2['Close'] = scaler.fit_transform(df2.Close.values.reshape(-1, 1))
df2['Volume'] = scaler.fit_transform(df2.Volume.values.reshape(-1, 1))

df3 = df2[['Open', 'High', 'Low', 'Volume', 'Close']].values

df3.shape
# Out:
# (2265, 5)

# %% [markdown]
# ### Tensorflow Modeling

# %% [markdown]
# #### Preparing Data for time series
# We'll utilize the prices from the previous 10 days to forecast the next day's price. Let's create the sequences accordingly.

# %%
len(df3) - 11 + 1
# Out:
# 2255

# %%
T = 11 # sequence length
sequences = []
for index in range(len(df3) - T + 1):
    sequences.append(df3[index: index + T])

sequences = np.array(sequences)
print(sequences.shape)
# Out:
# (2255, 11, 5)

# %% [markdown]
# #### Splitting the data

# %%
def split_data(sequences):
    df_train, df_test = train_test_split(sequences,
                                         test_size=0.2, shuffle=False)
    df_val, df_test = train_test_split(df_test,
                                        test_size=0.5, shuffle=False)
    return df_train, df_val, df_test

# %%
df_train, df_val, df_test = split_data(sequences)
print('Train shape:', df_train.shape,'Validation shape:', df_val.shape,
      'Test shape:', df_test.shape)
# Out:
# Train shape: (1804, 11, 5) Validation shape: (225, 11, 5) Test shape: (226, 11, 5)

# %%
X_train = df_train[:,:-1,:]
Y_train = df_train[:, -1, -1]

X_valid = df_val[:,:-1,:]
Y_valid = df_val[:, -1, -1]

X_test = df_test[:,:-1,:]
Y_test = df_test[:, -1, -1]

# %% [markdown]
# #### Defining Model

# %%
K = 1
D = df3.shape[1]
T = 10

# %%
i = Input(shape=(T,D))
x = LSTM(64, return_sequences=True)(i)
x = LSTM(128, return_sequences=False)(x)
# x = LSTM(32, return_sequences=False)(x)
x = Dense(50)(x)
x = Dense(K)(x)

model = Model(i,x)

# %%
model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['accuracy']
)

print('Training Model')
r = model.fit(
    X_train,
    Y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_valid, Y_valid)
)
# Out:
# Training Model
# Epoch 1/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.0000e+00 - loss: 0.0808 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 2/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0000e+00 - loss: 0.0014 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 3/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 9.9146e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0030
# Epoch 4/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 8.9450e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0048
# Epoch 5/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 8.2723e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0028
# Epoch 6/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 9.0002e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0041
# Epoch 7/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.0000e+00 - loss: 8.0778e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0026
# Epoch 8/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.0000e+00 - loss: 7.9177e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0030
# Epoch 9/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0000e+00 - loss: 7.0788e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0019
# Epoch 10/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 7.7734e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 11/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 7.8389e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0034
# Epoch 12/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 7.5898e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0021
# Epoch 13/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 7.3323e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 14/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 7.3177e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0021
# Epoch 15/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 7.6296e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0025
# Epoch 16/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 7.1711e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0027
# Epoch 17/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0000e+00 - loss: 6.6250e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0020
# Epoch 18/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.0000e+00 - loss: 6.8982e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0026
# Epoch 19/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.0000e+00 - loss: 7.1171e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0022
# Epoch 20/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 6.7687e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 21/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 5.7736e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 22/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 5.5867e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 23/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 5.4705e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0022
# Epoch 24/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 5.3496e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0028
# Epoch 25/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 6.0061e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0022
# Epoch 26/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 5.4852e-04 - val_accuracy: 0.0000e+00 - val_loss: 9.7442e-04
# Epoch 27/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0000e+00 - loss: 5.5260e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0019
# Epoch 28/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.0000e+00 - loss: 5.3124e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 29/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.0000e+00 - loss: 5.2250e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 30/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 4.7045e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 31/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 6.7540e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0022
# Epoch 32/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.0000e+00 - loss: 4.8874e-04 - val_accuracy: 0.0000e+00 - val_loss: 7.9349e-04
# Epoch 33/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.0000e+00 - loss: 5.2875e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0019
# Epoch 34/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.0000e+00 - loss: 4.9733e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.9811e-04
# Epoch 35/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.0000e+00 - loss: 4.3917e-04 - val_accuracy: 0.0000e+00 - val_loss: 9.5492e-04
# Epoch 36/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.0000e+00 - loss: 4.1762e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 37/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 5.0542e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0028
# Epoch 38/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 4.9981e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 39/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 4.7297e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 40/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 5.2181e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.1823e-04
# Epoch 41/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 4.4962e-04 - val_accuracy: 0.0000e+00 - val_loss: 7.8429e-04
# Epoch 42/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 4.4353e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 43/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 4.2433e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.9504e-04
# Epoch 44/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0000e+00 - loss: 4.6054e-04 - val_accuracy: 0.0000e+00 - val_loss: 6.8221e-04
# Epoch 45/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.0000e+00 - loss: 4.1516e-04 - val_accuracy: 0.0000e+00 - val_loss: 5.2486e-04
# Epoch 46/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.0000e+00 - loss: 3.7220e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 47/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 3.7970e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 48/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 3.7856e-04 - val_accuracy: 0.0000e+00 - val_loss: 7.0567e-04
# Epoch 49/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 4.2612e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 50/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0000e+00 - loss: 3.5892e-04 - val_accuracy: 0.0000e+00 - val_loss: 5.9596e-04

# %%
plt.plot(r.history['loss'], label='Train Loss')
plt.plot(r.history['val_loss'], label='Val Loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='vald accuracy')
plt.legend()

# %%
Y_pred = model.predict(X_test)

test_loss = model.evaluate(X_test, Y_test)
print('Test Loss:', test_loss)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0015 - loss: 0.0016
# Test Loss: [0.002273600548505783, 0.0044247787445783615]

# %%
plt.figure(figsize=(12,6))
idx = 0
plt.plot(Y_test, color='#2a9d8f', label='Actual')
plt.plot(Y_pred, color='#f4a261', label='Predicted')
plt.xlabel('Time [days]', fontsize=15)
plt.ylabel('Normalized Price', fontsize=15)
plt.title(f'{COMPANY_NAME} Stock Price Prediction Curve')
plt.legend(loc='best', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 10, 5)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 10, 64)              │          17,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 128)                 │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 50)                  │           6,450 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 369,713 (1.41 MB)
#  Trainable params: 123,237 (481.39 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 246,476 (962.80 KB)

# %%
predicted_prices = model.predict(X_test)
df_pred = df.iloc[-len(predicted_prices):].copy()
df_pred['Predicted Close'] = predicted_prices
df_pred['Open'] = df_pred['Open']
df_pred['High'] = df_pred['High']
df_pred['Low'] = df_pred['Low']
df_pred['Close'] = df_pred['Predicted Close']
final_df = df_pred[['Open', 'High', 'Low', 'Close', 'Volume']].copy()

final_df.index = pd.to_datetime(df_pred.index)

mpf.plot(
    final_df,
    type='candle',
    volume=True,
    style='charles',
    title='Predicted Candlestick Chart',
    ylabel = 'Price',
    ylabel_lower = 'Volume',
    figsize=(15,8)
)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
87493896484375,24.296491622924805,23.93680191040039,24.23692512512207,24.38665008544922,24.757509231567383,24.962512969970703,25.063861846923828,24.877281188964844,24.861160278320312,24.918750762939453,25.218189239501953,25.19515609741211,25.158306121826172,25.126054763793945,25.190555572509766,24.9947566986084,25.073074340820312,24.884197235107422,24.778236389160156,24.63311767578125,24.605480194091797,24.416593551635742,24.439632415771484,24.584747314453125,24.815088272094727,24.808181762695312,24.960208892822266,24.306026458740234,23.75550079345703,24.287601470947266,24.865760803222656,25.74568748474121,26.621000289916992,26.471269607543945,26.162607192993164,26.160308837890625,26.155698776245117,26.40216636657715,25.96220588684082,26.001365661621094,26.049741744995117,26.247838973999023,25.840126037597656,26.040531158447266,25.9184455871582 ...

# %%
latest_preds = []
last_seq = X_test[:-1]

for i in range(10):
    prediction = model.predict(last_seq)
    latest_preds.append(prediction)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
df = df.reset_index()

# %%
predicted_data_next = np.array(latest_preds).reshape(-1,5)
last_date = df['Date'].max()

next_10_days = [last_date + timedelta(days=i) for i in range(1,11)]

for i, feature_name in enumerate(['Open','High','Low','Volume','Close']):
    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=next_10_days,
        y=predicted_data_next[:,i],
        mode='lines+markers',
        name=f'Predicted {feature_name.capitalize()} Prices',
        line=dict(color='#f4a261'),
        marker=dict(color='#f4a261')
    ))

    fig.update_layout(
        title=f'Predicted {feature_name.capitalize()} Prices for the next 10 days',
        xaxis_title='Date',
        yaxis_title=f'{feature_name.capitalize()} Price',
        plot_bgcolor='White'
    )
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61f2050b-2304-40b2-9df4-f1d50a46a0fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61f2050b-2304-40b2-9df4-f1d50a46a0fc")) {                    Plotly.newPlot(                        "61f2050b-2304-40b2-9df4-f1d50a46a0fc",                        [{"line":{"color":"#f4a261"},"marker":{"color":"#f4a261"},"mode":"lines+markers","name":"Predicted Open Prices","x":["2025-01-14T00:00:00-05:00","2025-01-15T00:00:00-05:00","2025-01-16T00:00:00-05:00","2025-01-17T00:00:00-05:00","2025-01-18T00:00:00-05:00","2025-01-19T00:00:00-05:00","2025-01-20T00:00:00-05:00","2025-01-21T00:00:00-05:00","2025-01-22T00:00:00-05:00","2025-01-23T00:00:00-05:00"],"y":[0.34087798,0.33957186,0.29493836,0.2575115,0.27320597,0.2475166,0.23606507,0.23384199,0.2627326,0.20477447,0.26411992,0.36283898,0.37658405,0.41549248,0.40362197,0.45008793,0.54218805,0.58228844,0.5918771,0.66721773,0.71530086,0.65915406,0.60521746,0.6358014,0.59027046,0.6820775,0.6802918,0.7095742,0.6290823,0.6184735,0.7213131,0.7089171,0.6581173,0.7127046,0.7578994,0.7249251,0.6341878,0.68140453,0.69064474,0.71811223,0.8014407,0.84120494,0.8752782,0.93050724,0.82232904,0.34087798,0.33957186,0.29493836,0.2575115,0.27320597,0.2475166,0.23606507,0.23384199,0.2627326,0.20477447,0.26411992,0.36283898,0.37658405,0.41549248,0.40362197,0.45008793,0.54218805,0.58228844,0.5918771,0.66721773,0.71530086,0.65915406,0.60521746,0.6358014,0.59027046,0.6820775,0.6802918,0.7095742,0.6290823,0.6184735,0.7213131,0.7089171,0.6581173,0.7127046,0.7578994,0.7249251,0.6341878,0.68140453,0.69064474,0.71811223,0.8014407,0.84120494,0.8752782,0.93050724,0.82232904,0.34087798,0.33957186,0.29493836,0.2575115,0.27320597,0.2475166,0.23606507,0.23384199,0.2627326,0.20477447,0.26411992,0.36283898,0.37658405,0.41549248,0.40362197,0.45008793,0.54218805,0.58228844,0.5918771,0.66721773,0.71530086,0.65915406,0.60521746,0.6358014,0.59027046,0.6820775,0.6802918,0.7095742,0.6290823,0.6184735,0.7213131,0.7089171,0.6581173,0.7127046,0.7578994,0.7249251,0.6341878,0.68140453,0.69064474,0.71811223,0.8014407,0.84120494,0.8752782,0.93050724,0.82232904,0.34087798,0.33957186,0.29493836,0.2575115,0.27320597,0.2475166,0.23606507,0.23384199,0.2627326,0.20477447,0.26411992,0.36283898,0.37658405,0.41549248,0.40362197,0.45008793,0.54218805,0.58228844,0.5918771,0.66721773,0.71530086,0.65915406,0.60521746,0.6358014,0.59027046,0.6820775,0.6802918,0.7095742,0.6290823,0.6184735,0.7213131,0.7089171,0.6581173,0.7127046,0.7578994,0.7249251,0.6341878,0.68140453,0.69064474,0.71811223,0.8014407,0.84120494,0.8752782,0.93050724,0.82232904,0.34087798,0.33957186,0.29493836,0.2575115,0.27320597,0.2475166,0.23606507,0.23384199,0.2627326,0.20477447,0.26411992,0.36283898,0.37658405,0.41549248,0.40362197,0.45008793,0.54218805,0.58228844,0.5918771,0.66721773,0.71530086,0.65915406,0.60521746,0.6358014,0.59027046,0.6820775,0.6802918,0.7095742,0.6290823,0.6184735,0.7213131,0.7089171,0.6581173,0.7127046,0.7578994,0.7249251,0.6341878,0.68140453,0.69064474,0.71811223,0.8014407,0.84120494,0.8752782,0.93050724,0.82232904,0.34087798,0.33957186,0.29493836,0.2575115,0.27320597,0.2475166,0.23606507,0.23384199,0.2627326,0.20477447,0.26411992,0.36283898,0.37658405,0.41549248,0.40362197,0.45008793,0.54218805,0.58228844,0.5918771,0.66721773,0.71530086,0.65915406,0.60521746,0.6358014,0.59027046,0.6820775,0.6802918,0.7095742,0.6290823,0.6184735,0.7213131,0.7089171,0.6581173,0.7127046,0.7578994,0.7249251,0.6341878,0.68140453,0.69064474,0.71811223,0.8014407,0.84120494,0.8752782,0.93050724,0.82232904,0.34087798,0.33957186,0.29493836,0.2575115,0.27320597,0.2475166,0.23606507,0.23384199,0.2627326,0.20477447,0.26411992,0.36283898,0.37658405,0.41549248,0.40362197,0.45008793,0.542 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cb544d40-51d3-43d9-a742-8c93f3d514c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb544d40-51d3-43d9-a742-8c93f3d514c0")) {                    Plotly.newPlot(                        "cb544d40-51d3-43d9-a742-8c93f3d514c0",                        [{"line":{"color":"#f4a261"},"marker":{"color":"#f4a261"},"mode":"lines+markers","name":"Predicted High Prices","x":["2025-01-14T00:00:00-05:00","2025-01-15T00:00:00-05:00","2025-01-16T00:00:00-05:00","2025-01-17T00:00:00-05:00","2025-01-18T00:00:00-05:00","2025-01-19T00:00:00-05:00","2025-01-20T00:00:00-05:00","2025-01-21T00:00:00-05:00","2025-01-22T00:00:00-05:00","2025-01-23T00:00:00-05:00"],"y":[0.33315974,0.33390814,0.25539464,0.2663571,0.28616723,0.23891352,0.2338391,0.2275402,0.23992623,0.21918125,0.25039774,0.35872856,0.39141753,0.41513512,0.4115542,0.44860572,0.6094807,0.5323976,0.583079,0.6915476,0.